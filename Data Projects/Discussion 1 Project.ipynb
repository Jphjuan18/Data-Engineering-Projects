# %%
import pandas as pd
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('googletrendsaaplbtc.csv',header = 1) #,index_col = 'Week')

# %%
df
# Out:
#            Week  iPhone: (Worldwide)  Bitcoin: (Worldwide)  \
# 0    2017-01-01                   51                     3
# 1    2017-01-08                   48                     2
# 2    2017-01-15                   47                     2
# 3    2017-01-22                   46                     2
# 4    2017-01-29                   44                     2
# ..          ...                  ...                   ...
# 242  2021-08-22                   42                     9
# 243  2021-08-29                   43                     8
# 244  2021-09-05                   44                    11
# 245  2021-09-12                   66                     8
# 246  2021-09-19                   57                    10
#
#     Cryptocurrency: (Worldwide)  Apple: (Worldwide)
# 0                            <1                  18
# 1                            <1                  16
# 2                            <1                  16
# ...

# %%
#df['Week']

# %%
import pandas_datareader.data as web
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

# %%
#weeks = []
#weeks.append(df['Week'])

# %%
#weeks

# %%
style.use('ggplot')

# %%
start = dt.datetime(2017,1,1)
end = dt.datetime(2021,11,20)

# %%
#print(web.DataReader("TSLA",'yahoo',start,end))

# %%
btcprice = web.DataReader("BTC-USD", 'yahoo', start, end)

# %%
aaplprice = web.DataReader("AAPL", 'yahoo', start, end)

# %%
aaplprice.to_excel('aaplprice.xlsx')

# %%
aaplprice
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-01-03   29.082500   28.690001   28.950001   29.037500  115127600.0
# 2017-01-04   29.127501   28.937500   28.962500   29.004999   84472400.0
# 2017-01-05   29.215000   28.952499   28.980000   29.152500   88774400.0
# 2017-01-06   29.540001   29.117500   29.195000   29.477501  127007600.0
# 2017-01-09   29.857500   29.485001   29.487499   29.747499  134247600.0
# ...                ...         ...         ...         ...          ...
# 2021-09-22  146.429993  143.699997  144.449997  145.850006   76404300.0
# 2021-09-23  147.080002  145.639999  146.649994  146.830002   64838200.0
# 2021-09-24  147.470001  145.559998  145.660004  146.919998   53434200.0
# 2021-09-27  145.960007  143.820007  145.470001  145.369995   74031500.0
# 2021-09-28  144.750000  141.699997  143.250000  141.910004  108392608.0
#
#              Adj Close
# Date
# 2017-01-03   27.372362
# 2017-01-04   27.341724
# ...

# %%
#aapleopen = []
#aapleopen.append(aaplprice['Open'])
#btcopen = []
#btcopen.append(btcprice['Open'])

# %%
aaplprice.drop(['High','Low', 'Close', 'Volume', 'Adj Close'], axis=1, inplace=True)

# %%
btcprice.drop(['High','Low', 'Close', 'Volume', 'Adj Close'], axis=1, inplace=True)

# %%
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in __new__(cls, path, engine, **kwargs)
#     712                 try:
# --> 713                     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#     714                     if engine == "auto":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     232     def __call__(self, *args, **kwds):
# --> 233         return self.__func__(*args, **kwds)
#     234
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_config/config.py in _get_option(pat, silent)
#     104 def _get_option(pat: str, silent: bool = False):
# --> 105     key = _get_single_key(pat, silent)
#     106
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_config/config.py in _get_single_key(pat, silent)
# ...

# %%
weeks[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-68888c266711> in <module>
# ----> 1 weeks[7]
#
# IndexError: list index out of range

# %%
btcprice.append(weeks)
# Out:
#                              Open           0           1           2  \
# 2017-01-01 00:00:00    963.658020         NaN         NaN         NaN
# 2017-01-02 00:00:00    998.617004         NaN         NaN         NaN
# 2017-01-03 00:00:00   1021.599976         NaN         NaN         NaN
# 2017-01-04 00:00:00   1044.400024         NaN         NaN         NaN
# 2017-01-05 00:00:00   1156.729980         NaN         NaN         NaN
# ...                           ...         ...         ...         ...
# 2021-09-24 00:00:00  42840.890625         NaN         NaN         NaN
# 2021-09-25 00:00:00  42721.628906         NaN         NaN         NaN
# 2021-09-26 00:00:00  43234.183594         NaN         NaN         NaN
# 2021-09-28 00:00:00  42144.960938         NaN         NaN         NaN
# Week                          NaN  2017-01-01  2017-01-08  2017-01-15
#
#                               3           4           5           6  \
# ...

# %%
btcprice = btcprice.rename(column={[0]:"Week"})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-633f2ec25dc4> in <module>
# ----> 1 btcprice = btcprice.rename(column={[0]:"Week"})
#
# TypeError: unhashable type: 'list'

# %%
btcprice
# Out:
#                     Open
# Date
# 2017-01-03   1021.599976
# 2017-01-04   1044.400024
# 2017-01-05   1156.729980
# 2017-01-06   1014.239990
# 2017-01-07    903.487000
# ...                  ...
# 2021-09-23  44894.300781
# 2021-09-24  42840.890625
# 2021-09-25  42721.628906
# 2021-09-26  43234.183594
# 2021-09-28  42144.960938
#
# [1726 rows x 1 columns]

# %%
df.append(aaplprice)
# Out:
#                            Week  iPhone: (Worldwide)  Bitcoin: (Worldwide)  \
# 0                    2017-01-01                 51.0                   3.0
# 1                    2017-01-08                 48.0                   2.0
# 2                    2017-01-15                 47.0                   2.0
# 3                    2017-01-22                 46.0                   2.0
# 4                    2017-01-29                 44.0                   2.0
# ...                         ...                  ...                   ...
# 2021-09-22 00:00:00         NaN                  NaN                   NaN
# 2021-09-23 00:00:00         NaN                  NaN                   NaN
# 2021-09-24 00:00:00         NaN                  NaN                   NaN
# 2021-09-27 00:00:00         NaN                  NaN                   NaN
# 2021-09-28 00:00:00         NaN                  NaN                   NaN
#
# ...

# %%
btcprice["Open"].plot()
fig = plt.gcf()
fig.set_size_inches(15, 8)

# %%
aaplprice["Open"].plot()
fig = plt.gcf()
fig.set_size_inches(15, 8)
