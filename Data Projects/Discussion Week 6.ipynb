# %%
#!conda install -c conda-forge seaborn phik -y

# %%
import pandas as pd
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('GTCovid.csv',header = 2, index_col = 'Week')

# %%
df
# Out:
#          Mask  Vaccine  COVID  Hotel  Flights
# Week
# 1/5/20      3        2      0     22       19
# 1/12/20     3        2      0     24       18
# 1/19/20     4        2      0     24       17
# 1/26/20     8        2      0     21       15
# 2/2/20      6        2      0     21       15
# ...       ...      ...    ...    ...      ...
# 8/22/21    12       33     87     20       10
# 8/29/21    10       35     89     21       10
# 9/5/21      9       25     72     21       11
# 9/12/21     8       25     64     21       11
# 9/19/21     8       21     56     22       11
#
# [90 rows x 5 columns]

# %%
#report = ProfileReport(df)
#report.to_file('GTCovid.html')
# Out:
# Summarize dataset:   0%|          | 0/19 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
import phik
import seaborn as sns

# %%
#plt.figure(figsize = (15,10))
fig, ax = plt.subplots(figsize = (15, 10))
sns.lineplot( data=df)
plt.show()

# %%
plt.figure(figsize = (15,15))
sns.heatmap(df.corr())
plt.show()
