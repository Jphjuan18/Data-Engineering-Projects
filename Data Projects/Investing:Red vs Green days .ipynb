# %%
import pandas_datareader.data as web
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np

# %%
#pip install yfinance
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: yfinance in /usr/local/lib/python3.9/site-packages (0.1.70)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.9/site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.9/site-packages (from yfinance) (1.22.3)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.9/site-packages (from yfinance) (1.4.2)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.9/site-packages (from yfinance) (4.8.0)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.9/site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/site-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/site-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.24.0->yfinance) (1.16.0)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install pandas-datareader

# %%
style.use('ggplot')

# %%
start = dt.datetime(2010, 1, 3)
end = dt.datetime(2021,11,20)

# %%
print(web.DataReader("TSLA",'yahoo',2022-1-1,end).tail())
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2021-11-15  1031.979980   978.599976  1017.630005  1013.390015  34775600.0
# 2021-11-16  1057.199951  1002.179993  1003.309998  1054.729980  26542400.0
# 2021-11-17  1119.640015  1055.500000  1063.510010  1089.010010  31445400.0
# 2021-11-18  1112.000000  1075.020020  1106.550049  1096.380005  20898900.0
# 2021-11-19  1138.719971  1092.699951  1098.869995  1137.060059  21642300.0
#
#               Adj Close
# Date
# 2021-11-15  1013.390015
# 2021-11-16  1054.729980
# 2021-11-17  1089.010010
# 2021-11-18  1096.380005
# 2021-11-19  1137.060059

# %%
prices = web.DataReader("SPY", 'yahoo', start, end)
returns = prices.pct_change()

# %%
last_price = prices[:-1]

# %%
prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2993 entries, 2010-01-04 to 2021-11-19
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       2993 non-null   float64
#  1   Low        2993 non-null   float64
#  2   Open       2993 non-null   float64
#  3   Close      2993 non-null   float64
#  4   Volume     2993 non-null   float64
#  5   Adj Close  2993 non-null   float64
# dtypes: float64(6)
# memory usage: 163.7 KB

# %%
#Number of simulations
num_simulations = 10
num_days = 252

# %%
simulation_df = pd.DataFrame()

# %%
for x in range(num_simulations):
    count = 0
    daily_vol = returns.std()
    
    price_series = []
    
    price = last_price * (1 + np.random.normal(0, daily_vol))
    price_series.append(price)
    
    for y in range(num_days):
        if count == 251:
               break
        price = price_series[count] * (1 + np.random.normal(0, daily_vol))
        price_series.append(price)
        count =+ 1

# %%
simulation_df[x] = price_series

# %%
simulation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   9       253 non-null    object
# dtypes: object(1)
# memory usage: 2.1+ KB

# %%
simulation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   9       253 non-null    object
# dtypes: object(1)
# memory usage: 2.1+ KB

# %%
price["Open"].plot()
price["High"].plot()
price["Low"].plot()
price["Close"].plot()
fig = plt.gcf()
fig.set_size_inches(15, 8)

# %%
import pandas as pd
from pandas_profiling import ProfileReport
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/juanhernandez/Desktop/VS Code Python/Data Projects/Investing:Red vs Green days .ipynb Cell 17' in <module>
#       <a href='vscode-notebook-cell:/Users/juanhernandez/Desktop/VS%20Code%20Python/Data%20Projects/Investing%3ARed%20vs%20Green%20days%20.ipynb#ch0000016?line=0'>1</a> import pandas as pd
# ----> <a href='vscode-notebook-cell:/Users/juanhernandez/Desktop/VS%20Code%20Python/Data%20Projects/Investing%3ARed%20vs%20Green%20days%20.ipynb#ch0000016?line=1'>2</a> from pandas_profiling import ProfileReport
#       <a href='vscode-notebook-cell:/Users/juanhernandez/Desktop/VS%20Code%20Python/Data%20Projects/Investing%3ARed%20vs%20Green%20days%20.ipynb#ch0000016?line=2'>3</a> import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
df = pd.read_csv('google_trends.csv',header = 1)
